# %%
import time
import pandas as pd
import threading

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from concrete.ml.sklearn import KNeighborsClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot as plt
from sklearn import metrics
from sklearn.metrics import classification_report

# %% [markdown]
# # Small Random Dataset - 100 samples

# %% [markdown]
# Make classification samples and perform train and test split

# %%
sd_x, sd_y = make_classification(n_samples=100, class_sep=2, n_features=30, random_state=42)
print("X Minimum: ", sd_x.min())
print("X Maximum: ", sd_x.max())

sd_x_train, sd_x_test, sd_y_train, sd_y_test = train_test_split(sd_x, sd_y, test_size=0.1, random_state=42)
# Out:
# X Minimum:  -3.8192253511146537
# X Maximum:  3.625093656245981

# %% [markdown]
# Evaluate number of training and testing samples from train/test split

# %%
num_sd_x_training = len(sd_x_train)
num_sd_x_test = len(sd_x_test)
num_sd_y_training = len(sd_y_train)
num_sd_y_test = len(sd_y_test)

print("Number of x training: ", num_sd_x_training)
print("Number of x test: ", num_sd_x_test)
print("Number of y training: ", num_sd_y_training)
print("Number of y test: ", num_sd_y_test)
# Out:
# Number of x training:  90
# Number of x test:  10
# Number of y training:  90
# Number of y test:  10

# %%
print("sd_x_train shape: ", sd_x_train.shape)
print("sd_x_test shape: ", sd_x_test.shape)
print("sd_y_train shape: ", sd_y_train.shape)
print("sd_y_test shape: ", sd_y_train.shape)
# Out:
# sd_x_train shape:  (90, 30)
# sd_x_test shape:  (10, 30)
# sd_y_train shape:  (90,)
# sd_y_test shape:  (90,)

# %% [markdown]
# Initialise Model and Perform Fitting and Prediction

# %%
sd_total_start_time = time.time()

sd_model = KNeighborsClassifier(n_bits=8, n_neighbors=3)

sd_ml_start_time = time.time()

sd_model.fit(sd_x_train, sd_y_train)
sd_y_pred_clear = sd_model.predict(sd_x_test)

tag_context = threading.local()
tag_context.stack = []

sd_model.compile(sd_x_train)

sd_ml_end_time = time.time()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 13
#      10 tag_context = threading.local()
#      11 tag_context.stack = []
# ---> 13 sd_model.compile(sd_x_train)
#      15 sd_ml_end_time = time.time()
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/ml/sklearn/base.py:669, in BaseEstimator.compile(self, X, configuration, ciphertext_format, artifacts, show_mlir, p_error, global_p_error, verbose, device)
#     664         configuration = cp.Configuration()
#     665     configuration.security_level = (
#     666         cp.compilation.configuration.SecurityLevel.SECURITY_132_BITS
#     667     )
# --> 669 self.fhe_circuit_ = module_to_compile.compile(
#     670     inputset,
#     671     configuration=configuration,
#     672     artifacts=artifacts,
#     673     show_mlir=show_mlir,
#     674     p_error=p_error,
#     675     global_p_error=global_p_error,
#     676     verbose=verbose,
#     677     single_precision=False,
#     678     use_gpu=use_gpu,
#     679     compress_input_ciphertexts=enable_input_compression,
#     680     compress_evaluation_keys=enable_key_compression,
#     681 )
#     683 self._is_compiled = True
#     684 self._compiled_for_cuda = use_gpu
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/fhe/compilation/compiler.py:203, in Compiler.compile(self, inputset, configuration, artifacts, **kwargs)
#     201 if conf.composable:
#     202     self._module_compiler.composition = AllComposable()
# --> 203 fhe_module = self._module_compiler.compile(
#     204     {self._function_name: inputset}, configuration=conf, module_artifacts=art
#     205 )
#     206 return Circuit(fhe_module)
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/fhe/compilation/module_compiler.py:423, in ModuleCompiler.compile(self, inputsets, configuration, module_artifacts, **kwargs)
#     415     graphs[name] = function.graph
#     417 # pylint: disable=protected-access
#     418 mlir_module = GraphConverter(
#     419     configuration,
#     420     self.composition.get_rules_iter(
#     421         list(filter(None, [f.graph for f in self.functions.values()]))
#     422     ),
# --> 423 ).convert_many(graphs, mlir_context)
#     424 mlir_str = str(mlir_module).strip()
#     425 dbg.debug_mlir(mlir_str)
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/fhe/mlir/converter.py:106, in Converter.convert_many(self, graphs, mlir_context)
#     101 location = graph.location.split(":")
#     102 with MlirLocation.file(
#     103     location[0], line=int(location[1]), col=0, context=context
#     104 ):
# --> 106     @func.FuncOp.from_py_func(*input_types, name=name)
#     107     def main(*args):
#     108         for index, node in enumerate(graph.ordered_inputs()):
#     109             conversion = Conversion(node, args[index])
#
# File /opt/anaconda3/lib/python3.12/site-packages/mlir/dialects/_func_ops_ext.py:187, in FuncOp.from_py_func.<locals>.decorator(f)
#     185 if has_arg_func_op:
#     186   func_kwargs["func_op"] = func_op
# --> 187 return_values = f(*func_args, **func_kwargs)
#     188 if not implicit_return:
#     189   return_types = list(results)
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/fhe/mlir/converter.py:129, in Converter.convert_many.<locals>.main(*args)
#     123     self.trace_progress(
#     124         self.configuration, progress_index, ordered_nodes
#     125     )
#     126     preds = [
#     127         ctx.conversions[pred] for pred in graph.ordered_preds_of(node)
#     128     ]
# --> 129     self.node(ctx, node, preds)
#     130 self.trace_progress(
#     131     self.configuration, len(ordered_nodes), ordered_nodes
#     132 )
#     134 outputs = []
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/fhe/mlir/converter.py:310, in Converter.node(self, ctx, node, preds)
#     307 assert operation not in ["convert", "node"]
#     309 converter = getattr(self, operation, self.tlu)
# --> 310 conversion = converter(ctx, node, preds)
#     311 conversion.set_original_bit_width(node.properties["original_bit_width"])
#     313 ctx.conversions[node] = conversion
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/fhe/mlir/converter.py:803, in Converter.tlu(self, ctx, node, preds)
#     792             variable_input_messages.append(
#     793                 "("
#     794                 f"note that it's assigned {variable_input.bit_width}-bits "
#     795                 f"during compilation because of its relation with other operations"
#     796                 ")"
#     797             )
#     799         highlights = {
#     800             variable_input.origin: variable_input_messages,
#     801             node: f"but only up to {MAXIMUM_TLU_BIT_WIDTH}-bit table lookups are supported",
#     802         }
# --> 803         ctx.error(highlights)
#     805 tables = construct_deduplicated_tables(node, pred_nodes, self.configuration)
#     807 assert len(tables) > 0
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/fhe/mlir/context.py:272, in Context.error(self, highlights)
#     263 def error(self, highlights: Mapping[Node, Union[str, List[str]]]):
#     264     """
#     265     Fail compilation with an error.
#     266
#    (...)
#     269             nodes to highlight along with messages
#     270     """
# --> 272     GraphProcessor.error(self.graph, highlights)
#
# File /opt/anaconda3/lib/python3.12/site-packages/concrete/fhe/representation/graph.py:1040, in GraphProcessor.error(graph, highlights)
#    1035     highlights_with_location[node] = messages_with_location
#    1037 message = "Function you are trying to compile cannot be compiled\n\n" + graph.format(
#    1038     highlighted_nodes=highlights_with_location
#    1039 )
# -> 1040 raise RuntimeError(message)
#
# RuntimeError: Function you are trying to compile cannot be compiled
#
#    %0 = q_X                                     # EncryptedTensor<int8, shape=(1, 30)>          ∈ [-128, 127]
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ this 19-bit value is used as an input to a table lookup
#                                                                                                               (note that it's assigned 19-bits during compilation because of its relation with other operations)
#                                                                                                               /opt/anaconda3/lib/python3.12/site-packages/concrete/ml/sklearn/base.py:669
#    %1 = 2                                       # ClearScalar<uint2>                            ∈ [2, 2]                   @ Original distance
#    %2 = power(%0, %1)                           # EncryptedTensor<uint15, shape=(1, 30)>        ∈ [0, 16384]               @ Original distance
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ but only up to 16-bit table lookups are supported
#                                                                                                                                                /opt/anaconda3/lib/python3.12/site-packages/concrete/ml/sklearn/base.py:2419
#    %3 = sum(%2, axis=1, keepdims=True)          # EncryptedTensor<uint17, shape=(1, 1)>         ∈ [24334, 89609]           @ Original distance
#    %4 = 2                                       # ClearScalar<uint2>                            ∈ [2, 2]                   @ Original distance
#    %5 = multiply(%4, %0)                        # EncryptedTensor<int9, shape=(1, 30)>          ∈ [-256, 254]              @ Original distance
#    %6 = [[ 43  -5  ...   52 -44]]               # ClearTensor<int8, shape=(30, 90)>             ∈ [-128, 127]              @ Original distance
#    %7 = matmul(%5, %6)                          # EncryptedTensor<int19, shape=(1, 90)>         ∈ [-104078, 179218]        @ Original distance
#    %8 = subtract(%3, %7)                        # EncryptedTensor<int19, shape=(1, 90)>         ∈ [-89609, 190215]         @ Original distance
#    %9 = [[47708 44 ... 51 52950]]               # ClearTensor<uint17, shape=(1, 90)>            ∈ [24334, 89609]           @ Original distance
#   %10 = add(%8, %9)                             # EncryptedTensor<uint18, shape=(1, 90)>        ∈ [0, 257628]              @ Original distance
#   %11 = reshape(%10, newshape=(90,))            # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]
#   %12 = zeros()                                 # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 0]
#   %13 = [0 0 1 0 0 ... 0 1 1 0 1]               # ClearTensor<uint1, shape=(90,)>               ∈ [0, 1]
#   %14 = add(%13, %12)                           # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]
#   %15 = %11[0]                                  # EncryptedScalar<uint18>                       ∈ [0, 192625]              @ Stage_6_pass_6
#   %16 = %11[1]                                  # EncryptedScalar<uint18>                       ∈ [0, 153899]              @ Stage_6_pass_6
#   %17 = %11[2]                                  # EncryptedScalar<uint18>                       ∈ [0, 168634]              @ Stage_6_pass_6
#   %18 = %11[3]                                  # EncryptedScalar<uint18>                       ∈ [0, 193430]              @ Stage_6_pass_6
#   %19 = %11[4]                                  # EncryptedScalar<uint18>                       ∈ [0, 169061]              @ Stage_6_pass_6
#   %20 = %11[5]                                  # EncryptedScalar<uint18>                       ∈ [0, 155357]              @ Stage_6_pass_6
#   %21 = %11[6]                                  # EncryptedScalar<uint18>                       ∈ [0, 190864]              @ Stage_6_pass_6
#   %22 = %11[7]                                  # EncryptedScalar<uint18>                       ∈ [0, 146255]              @ Stage_6_pass_6
#   %23 = %11[8]                                  # EncryptedScalar<uint18>                       ∈ [0, 197239]              @ Stage_6_pass_6
#   %24 = %11[9]                                  # EncryptedScalar<uint18>                       ∈ [0, 158526]              @ Stage_6_pass_6
#   %25 = %11[10]                                 # EncryptedScalar<uint18>                       ∈ [0, 232208]              @ Stage_6_pass_6
#   %26 = %11[11]                                 # EncryptedScalar<uint18>                       ∈ [0, 143370]              @ Stage_6_pass_6
#   %27 = %11[12]                                 # EncryptedScalar<uint18>                       ∈ [0, 244186]              @ Stage_6_pass_6
#   %28 = %11[13]                                 # EncryptedScalar<uint18>                       ∈ [0, 209154]              @ Stage_6_pass_6
#   %29 = %11[14]                                 # EncryptedScalar<uint18>                       ∈ [0, 189862]              @ Stage_6_pass_6
#   %30 = %11[15]                                 # EncryptedScalar<uint18>                       ∈ [0, 149678]              @ Stage_6_pass_6
#   %31 = %11[16]                                 # EncryptedScalar<uint18>                       ∈ [0, 177620]              @ Stage_6_pass_6
#   %32 = %11[17]                                 # EncryptedScalar<uint18>                       ∈ [0, 181394]              @ Stage_6_pass_6
#   %33 = %11[18]                                 # EncryptedScalar<uint18>                       ∈ [0, 161787]              @ Stage_6_pass_6
#   %34 = %11[19]                                 # EncryptedScalar<uint18>                       ∈ [0, 153621]              @ Stage_6_pass_6
#   %35 = %11[20]                                 # EncryptedScalar<uint18>                       ∈ [0, 187845]              @ Stage_6_pass_6
#   %36 = %11[21]                                 # EncryptedScalar<uint18>                       ∈ [0, 179727]              @ Stage_6_pass_6
#   %37 = %11[22]                                 # EncryptedScalar<uint18>                       ∈ [0, 155693]              @ Stage_6_pass_6
#   %38 = %11[23]                                 # EncryptedScalar<uint18>                       ∈ [0, 162620]              @ Stage_6_pass_6
#   %39 = %11[24]                                 # EncryptedScalar<uint18>                       ∈ [0, 252063]              @ Stage_6_pass_6
#   %40 = %11[25]                                 # EncryptedScalar<uint18>                       ∈ [0, 187986]              @ Stage_6_pass_6
#   %41 = array([%15, %16, ...  %39, %40])        # EncryptedTensor<uint18, shape=(26,)>          ∈ [0, 252063]              @ Stage_6_pass_6
#   %42 = %11[64]                                 # EncryptedScalar<uint18>                       ∈ [0, 212946]              @ Stage_6_pass_6
#   %43 = %11[65]                                 # EncryptedScalar<uint18>                       ∈ [0, 137385]              @ Stage_6_pass_6
#   %44 = %11[66]                                 # EncryptedScalar<uint18>                       ∈ [0, 180988]              @ Stage_6_pass_6
#   %45 = %11[67]                                 # EncryptedScalar<uint18>                       ∈ [0, 196987]              @ Stage_6_pass_6
#   %46 = %11[68]                                 # EncryptedScalar<uint18>                       ∈ [0, 142266]              @ Stage_6_pass_6
#   %47 = %11[69]                                 # EncryptedScalar<uint18>                       ∈ [0, 164100]              @ Stage_6_pass_6
#   %48 = %11[70]                                 # EncryptedScalar<uint18>                       ∈ [0, 214620]              @ Stage_6_pass_6
#   %49 = %11[71]                                 # EncryptedScalar<uint18>                       ∈ [0, 145534]              @ Stage_6_pass_6
#   %50 = %11[72]                                 # EncryptedScalar<uint18>                       ∈ [0, 183169]              @ Stage_6_pass_6
#   %51 = %11[73]                                 # EncryptedScalar<uint18>                       ∈ [0, 239111]              @ Stage_6_pass_6
#   %52 = %11[74]                                 # EncryptedScalar<uint18>                       ∈ [0, 221537]              @ Stage_6_pass_6
#   %53 = %11[75]                                 # EncryptedScalar<uint18>                       ∈ [0, 208423]              @ Stage_6_pass_6
#   %54 = %11[76]                                 # EncryptedScalar<uint18>                       ∈ [0, 219468]              @ Stage_6_pass_6
#   %55 = %11[77]                                 # EncryptedScalar<uint18>                       ∈ [0, 136984]              @ Stage_6_pass_6
#   %56 = %11[78]                                 # EncryptedScalar<uint18>                       ∈ [0, 168439]              @ Stage_6_pass_6
#   %57 = %11[79]                                 # EncryptedScalar<uint18>                       ∈ [0, 171695]              @ Stage_6_pass_6
#   %58 = %11[80]                                 # EncryptedScalar<uint18>                       ∈ [0, 149419]              @ Stage_6_pass_6
#   %59 = %11[81]                                 # EncryptedScalar<uint18>                       ∈ [0, 194759]              @ Stage_6_pass_6
#   %60 = %11[82]                                 # EncryptedScalar<uint18>                       ∈ [0, 170015]              @ Stage_6_pass_6
#   %61 = %11[83]                                 # EncryptedScalar<uint18>                       ∈ [0, 154335]              @ Stage_6_pass_6
#   %62 = %11[84]                                 # EncryptedScalar<uint18>                       ∈ [0, 161754]              @ Stage_6_pass_6
#   %63 = %11[85]                                 # EncryptedScalar<uint18>                       ∈ [0, 168439]              @ Stage_6_pass_6
#   %64 = %11[86]                                 # EncryptedScalar<uint18>                       ∈ [0, 150980]              @ Stage_6_pass_6
#   %65 = %11[87]                                 # EncryptedScalar<uint18>                       ∈ [0, 146154]              @ Stage_6_pass_6
#   %66 = %11[88]                                 # EncryptedScalar<uint18>                       ∈ [0, 167948]              @ Stage_6_pass_6
#   %67 = %11[89]                                 # EncryptedScalar<uint18>                       ∈ [0, 171070]              @ Stage_6_pass_6
#   %68 = array([%42, %43, ...  %66, %67])        # EncryptedTensor<uint18, shape=(26,)>          ∈ [0, 239111]              @ Stage_6_pass_6
#   %69 = %14[0]                                  # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %70 = %14[1]                                  # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %71 = %14[2]                                  # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %72 = %14[3]                                  # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %73 = %14[4]                                  # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %74 = %14[5]                                  # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %75 = %14[6]                                  # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %76 = %14[7]                                  # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %77 = %14[8]                                  # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %78 = %14[9]                                  # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %79 = %14[10]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %80 = %14[11]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %81 = %14[12]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %82 = %14[13]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %83 = %14[14]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %84 = %14[15]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %85 = %14[16]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %86 = %14[17]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %87 = %14[18]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %88 = %14[19]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %89 = %14[20]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %90 = %14[21]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %91 = %14[22]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %92 = %14[23]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#   %93 = %14[24]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %94 = %14[25]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %95 = array([%69, %70, ...  %93, %94])        # EncryptedTensor<uint1, shape=(26,)>           ∈ [0, 1]                   @ Stage_6_pass_6
#   %96 = %14[64]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %97 = %14[65]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %98 = %14[66]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#   %99 = %14[67]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %100 = %14[68]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %101 = %14[69]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %102 = %14[70]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %103 = %14[71]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %104 = %14[72]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %105 = %14[73]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %106 = %14[74]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %107 = %14[75]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %108 = %14[76]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %109 = %14[77]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %110 = %14[78]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %111 = %14[79]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %112 = %14[80]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %113 = %14[81]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %114 = %14[82]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %115 = %14[83]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %116 = %14[84]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %117 = %14[85]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %118 = %14[86]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %119 = %14[87]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %120 = %14[88]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6
#  %121 = %14[89]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6
#  %122 = array([%96, %97, ... 120, %121])        # EncryptedTensor<uint1, shape=(26,)>           ∈ [0, 1]                   @ Stage_6_pass_6
#  %123 = subtract(%68, %41)                      # EncryptedTensor<int19, shape=(26,)>           ∈ [-163072, 163072]        @ Stage_6_pass_6.diff
#  %124 = 0                                       # ClearScalar<uint1>                            ∈ [0, 0]                   @ Stage_6_pass_6.max_value
#  %125 = maximum(%124, %123)                     # EncryptedTensor<uint18, shape=(26,)>          ∈ [0, 163072]              @ Stage_6_pass_6.max_value
#  %126 = add(%41, %125)                          # EncryptedTensor<uint18, shape=(26,)>          ∈ [35162, 252063]          @ Stage_6_pass_6.max_value
#  %127 = add(%41, %68)                           # EncryptedTensor<uint19, shape=(26,)>          ∈ [40371, 463654]          @ Stage_6_pass_6.swap_max_value
#  %128 = subtract(%127, %126)                    # EncryptedTensor<uint18, shape=(26,)>          ∈ [0, 219468]              @ Stage_6_pass_6.swap_max_value
#  %129 = %128[0]                                 # EncryptedScalar<uint18>                       ∈ [0, 189495]              @ Stage_6_pass_6.swap_max_value
#  %130 = (%11[0] = %129)                         # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %131 = %128[1]                                 # EncryptedScalar<uint18>                       ∈ [0, 137385]              @ Stage_6_pass_6.swap_max_value
#  %132 = (%130[1] = %131)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %133 = %128[2]                                 # EncryptedScalar<uint18>                       ∈ [0, 133609]              @ Stage_6_pass_6.swap_max_value
#  %134 = (%132[2] = %133)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %135 = %128[3]                                 # EncryptedScalar<uint18>                       ∈ [0, 193430]              @ Stage_6_pass_6.swap_max_value
#  %136 = (%134[3] = %135)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %137 = %128[4]                                 # EncryptedScalar<uint17>                       ∈ [0, 124809]              @ Stage_6_pass_6.swap_max_value
#  %138 = (%136[4] = %137)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %139 = %128[5]                                 # EncryptedScalar<uint18>                       ∈ [0, 139987]              @ Stage_6_pass_6.swap_max_value
#  %140 = (%138[5] = %139)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %141 = %128[6]                                 # EncryptedScalar<uint18>                       ∈ [0, 136946]              @ Stage_6_pass_6.swap_max_value
#  %142 = (%140[6] = %141)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %143 = %128[7]                                 # EncryptedScalar<uint18>                       ∈ [0, 134110]              @ Stage_6_pass_6.swap_max_value
#  %144 = (%142[7] = %143)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %145 = %128[8]                                 # EncryptedScalar<uint18>                       ∈ [0, 179975]              @ Stage_6_pass_6.swap_max_value
#  %146 = (%144[8] = %145)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %147 = %128[9]                                 # EncryptedScalar<uint18>                       ∈ [0, 143921]              @ Stage_6_pass_6.swap_max_value
#  %148 = (%146[9] = %147)                        # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %149 = %128[10]                                # EncryptedScalar<uint18>                       ∈ [0, 208281]              @ Stage_6_pass_6.swap_max_value
#  %150 = (%148[10] = %149)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %151 = %128[11]                                # EncryptedScalar<uint17>                       ∈ [0, 130962]              @ Stage_6_pass_6.swap_max_value
#  %152 = (%150[11] = %151)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %153 = %128[12]                                # EncryptedScalar<uint18>                       ∈ [0, 219468]              @ Stage_6_pass_6.swap_max_value
#  %154 = (%152[12] = %153)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %155 = %128[13]                                # EncryptedScalar<uint17>                       ∈ [0, 122358]              @ Stage_6_pass_6.swap_max_value
#  %156 = (%154[13] = %155)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %157 = %128[14]                                # EncryptedScalar<uint18>                       ∈ [0, 132615]              @ Stage_6_pass_6.swap_max_value
#  %158 = (%156[14] = %157)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %159 = %128[15]                                # EncryptedScalar<uint18>                       ∈ [0, 149678]              @ Stage_6_pass_6.swap_max_value
#  %160 = (%158[15] = %159)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %161 = %128[16]                                # EncryptedScalar<uint18>                       ∈ [0, 136891]              @ Stage_6_pass_6.swap_max_value
#  %162 = (%160[16] = %161)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %163 = %128[17]                                # EncryptedScalar<uint18>                       ∈ [0, 181394]              @ Stage_6_pass_6.swap_max_value
#  %164 = (%162[17] = %163)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %165 = %128[18]                                # EncryptedScalar<uint18>                       ∈ [0, 145201]              @ Stage_6_pass_6.swap_max_value
#  %166 = (%164[18] = %165)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %167 = %128[19]                                # EncryptedScalar<uint18>                       ∈ [0, 134646]              @ Stage_6_pass_6.swap_max_value
#  %168 = (%166[19] = %167)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %169 = %128[20]                                # EncryptedScalar<uint18>                       ∈ [0, 151955]              @ Stage_6_pass_6.swap_max_value
#  %170 = (%168[20] = %169)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %171 = %128[21]                                # EncryptedScalar<uint18>                       ∈ [0, 165456]              @ Stage_6_pass_6.swap_max_value
#  %172 = (%170[21] = %171)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %173 = %128[22]                                # EncryptedScalar<uint17>                       ∈ [0, 110719]              @ Stage_6_pass_6.swap_max_value
#  %174 = (%172[22] = %173)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %175 = %128[23]                                # EncryptedScalar<uint18>                       ∈ [0, 146154]              @ Stage_6_pass_6.swap_max_value
#  %176 = (%174[23] = %175)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %177 = %128[24]                                # EncryptedScalar<uint18>                       ∈ [0, 167556]              @ Stage_6_pass_6.swap_max_value
#  %178 = (%176[24] = %177)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %179 = %128[25]                                # EncryptedScalar<uint18>                       ∈ [0, 132523]              @ Stage_6_pass_6.swap_max_value
#  %180 = (%178[25] = %179)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %181 = %126[0]                                 # EncryptedScalar<uint18>                       ∈ [40371, 212946]          @ Stage_6_pass_6.swap_max_value
#  %182 = (%180[64] = %181)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %183 = %126[1]                                 # EncryptedScalar<uint18>                       ∈ [35162, 153899]          @ Stage_6_pass_6.swap_max_value
#  %184 = (%182[65] = %183)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %185 = %126[2]                                 # EncryptedScalar<uint18>                       ∈ [67459, 180988]          @ Stage_6_pass_6.swap_max_value
#  %186 = (%184[66] = %185)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %187 = %126[3]                                 # EncryptedScalar<uint18>                       ∈ [48304, 196987]          @ Stage_6_pass_6.swap_max_value
#  %188 = (%186[67] = %187)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %189 = %126[4]                                 # EncryptedScalar<uint18>                       ∈ [36439, 169061]          @ Stage_6_pass_6.swap_max_value
#  %190 = (%188[68] = %189)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %191 = %126[5]                                 # EncryptedScalar<uint18>                       ∈ [74854, 164100]          @ Stage_6_pass_6.swap_max_value
#  %192 = (%190[69] = %191)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %193 = %126[6]                                 # EncryptedScalar<uint18>                       ∈ [90616, 214620]          @ Stage_6_pass_6.swap_max_value
#  %194 = (%192[70] = %193)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %195 = %126[7]                                 # EncryptedScalar<uint18>                       ∈ [48083, 146255]          @ Stage_6_pass_6.swap_max_value
#  %196 = (%194[71] = %195)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %197 = %126[8]                                 # EncryptedScalar<uint18>                       ∈ [54318, 197239]          @ Stage_6_pass_6.swap_max_value
#  %198 = (%196[72] = %197)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %199 = %126[9]                                 # EncryptedScalar<uint18>                       ∈ [69338, 239111]          @ Stage_6_pass_6.swap_max_value
#  %200 = (%198[73] = %199)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %201 = %126[10]                                # EncryptedScalar<uint18>                       ∈ [76000, 232208]          @ Stage_6_pass_6.swap_max_value
#  %202 = (%200[74] = %201)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %203 = %126[11]                                # EncryptedScalar<uint18>                       ∈ [64664, 208423]          @ Stage_6_pass_6.swap_max_value
#  %204 = (%202[75] = %203)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %205 = %126[12]                                # EncryptedScalar<uint18>                       ∈ [56595, 244186]          @ Stage_6_pass_6.swap_max_value
#  %206 = (%204[76] = %205)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %207 = %126[13]                                # EncryptedScalar<uint18>                       ∈ [64531, 209154]          @ Stage_6_pass_6.swap_max_value
#  %208 = (%206[77] = %207)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %209 = %126[14]                                # EncryptedScalar<uint18>                       ∈ [76013, 189862]          @ Stage_6_pass_6.swap_max_value
#  %210 = (%208[78] = %209)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %211 = %126[15]                                # EncryptedScalar<uint18>                       ∈ [42563, 171695]          @ Stage_6_pass_6.swap_max_value
#  %212 = (%210[79] = %211)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %213 = %126[16]                                # EncryptedScalar<uint18>                       ∈ [55008, 177620]          @ Stage_6_pass_6.swap_max_value
#  %214 = (%212[80] = %213)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %215 = %126[17]                                # EncryptedScalar<uint18>                       ∈ [61564, 194759]          @ Stage_6_pass_6.swap_max_value
#  %216 = (%214[81] = %215)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %217 = %126[18]                                # EncryptedScalar<uint18>                       ∈ [62571, 170015]          @ Stage_6_pass_6.swap_max_value
#  %218 = (%216[82] = %217)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %219 = %126[19]                                # EncryptedScalar<uint18>                       ∈ [64368, 154335]          @ Stage_6_pass_6.swap_max_value
#  %220 = (%218[83] = %219)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %221 = %126[20]                                # EncryptedScalar<uint18>                       ∈ [65662, 187845]          @ Stage_6_pass_6.swap_max_value
#  %222 = (%220[84] = %221)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %223 = %126[21]                                # EncryptedScalar<uint18>                       ∈ [63929, 179727]          @ Stage_6_pass_6.swap_max_value
#  %224 = (%222[85] = %223)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %225 = %126[22]                                # EncryptedScalar<uint18>                       ∈ [76044, 155693]          @ Stage_6_pass_6.swap_max_value
#  %226 = (%224[86] = %225)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %227 = %126[23]                                # EncryptedScalar<uint18>                       ∈ [49905, 162620]          @ Stage_6_pass_6.swap_max_value
#  %228 = (%226[87] = %227)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %229 = %126[24]                                # EncryptedScalar<uint18>                       ∈ [66023, 252063]          @ Stage_6_pass_6.swap_max_value
#  %230 = (%228[88] = %229)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %231 = %126[25]                                # EncryptedScalar<uint18>                       ∈ [86301, 187986]          @ Stage_6_pass_6.swap_max_value
#  %232 = (%230[89] = %231)                       # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_6_pass_6.swap_max_value
#  %233 = 0                                       # ClearScalar<uint1>                            ∈ [0, 0]                   @ Stage_6_pass_6.max_label
#  %234 = greater(%123, %233)                     # EncryptedTensor<uint1, shape=(26,)>           ∈ [0, 1]                   @ Stage_6_pass_6.max_label
#  %235 = subtract(%122, %95)                     # EncryptedTensor<int2, shape=(26,)>            ∈ [-1, 1]                  @ Stage_6_pass_6.max_label
#  %236 = multiply(%235, %234)                    # EncryptedTensor<int2, shape=(26,)>            ∈ [-1, 1]                  @ Stage_6_pass_6.max_label
#  %237 = add(%95, %236)                          # EncryptedTensor<uint1, shape=(26,)>           ∈ [0, 1]                   @ Stage_6_pass_6.max_label
#  %238 = add(%95, %122)                          # EncryptedTensor<uint2, shape=(26,)>           ∈ [0, 2]                   @ Stage_6_pass_6.swap_max_label
#  %239 = subtract(%238, %237)                    # EncryptedTensor<uint1, shape=(26,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %240 = %239[0]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6.swap_max_label
#  %241 = (%14[0] = %240)                         # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %242 = %239[1]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6.swap_max_label
#  %243 = (%241[1] = %242)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %244 = %239[2]                                 # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %245 = (%243[2] = %244)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %246 = %239[3]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6.swap_max_label
#  %247 = (%245[3] = %246)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %248 = %239[4]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6.swap_max_label
#  %249 = (%247[4] = %248)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %250 = %239[5]                                 # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %251 = (%249[5] = %250)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %252 = %239[6]                                 # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %253 = (%251[6] = %252)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %254 = %239[7]                                 # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6.swap_max_label
#  %255 = (%253[7] = %254)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %256 = %239[8]                                 # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6.swap_max_label
#  %257 = (%255[8] = %256)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %258 = %239[9]                                 # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %259 = (%257[9] = %258)                        # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %260 = %239[10]                                # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6.swap_max_label
#  %261 = (%259[10] = %260)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %262 = %239[11]                                # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6.swap_max_label
#  %263 = (%261[11] = %262)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %264 = %239[12]                                # EncryptedScalar<uint1>                        ∈ [0, 0]                   @ Stage_6_pass_6.swap_max_label
#  %265 = (%263[12] = %264)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %266 = %239[13]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %267 = (%265[13] = %266)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %268 = %239[14]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %269 = (%267[14] = %268)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %270 = %239[15]                                # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6.swap_max_label
#  %271 = (%269[15] = %270)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %272 = %239[16]                                # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6.swap_max_label
#  %273 = (%271[16] = %272)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %274 = %239[17]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %275 = (%273[17] = %274)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %276 = %239[18]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %277 = (%275[18] = %276)                       # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_6_pass_6.swap_max_label
#  %278 = %239[19]                                # EncryptedScalar<uint1>                        ∈ [1, 1]                   @ Stage_6_pass_6.swap_max_label
# ...
# %4525 = array([%4523, %4524])                   # EncryptedTensor<uint17, shape=(2,)>           ∈ [35831, 87963]           @ Stage_0_pass_2
# %4526 = %4519[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_2
# %4527 = %4519[3]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_2
# %4528 = array([%4526, %4527])                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_2
# %4529 = %4519[8]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_2
# %4530 = %4519[10]                               # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_2
# %4531 = array([%4529, %4530])                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_2
# %4532 = subtract(%4525, %4522)                  # EncryptedTensor<int17, shape=(2,)>            ∈ [-4226, 36122]           @ Stage_0_pass_2.diff
# %4533 = 0                                       # ClearScalar<uint1>                            ∈ [0, 0]                   @ Stage_0_pass_2.max_value
# %4534 = maximum(%4533, %4532)                   # EncryptedTensor<uint16, shape=(2,)>           ∈ [0, 36122]               @ Stage_0_pass_2.max_value
# %4535 = add(%4522, %4534)                       # EncryptedTensor<uint17, shape=(2,)>           ∈ [35831, 87963]           @ Stage_0_pass_2.max_value
# %4536 = add(%4522, %4525)                       # EncryptedTensor<uint18, shape=(2,)>           ∈ [65447, 150219]          @ Stage_0_pass_2.swap_max_value
# %4537 = subtract(%4536, %4535)                  # EncryptedTensor<uint17, shape=(2,)>           ∈ [22347, 69010]           @ Stage_0_pass_2.swap_max_value
# %4538 = %4537[0]                                # EncryptedScalar<uint16>                       ∈ [22347, 58511]           @ Stage_0_pass_2.swap_max_value
# %4539 = (%4504[1] = %4538)                      # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_0_pass_2.swap_max_value
# %4540 = %4537[1]                                # EncryptedScalar<uint17>                       ∈ [32439, 69010]           @ Stage_0_pass_2.swap_max_value
# %4541 = (%4539[3] = %4540)                      # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_0_pass_2.swap_max_value
# %4542 = %4535[0]                                # EncryptedScalar<uint17>                       ∈ [35831, 77543]           @ Stage_0_pass_2.swap_max_value
# %4543 = (%4541[8] = %4542)                      # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_0_pass_2.swap_max_value
# %4544 = %4535[1]                                # EncryptedScalar<uint17>                       ∈ [42183, 87963]           @ Stage_0_pass_2.swap_max_value
# %4545 = (%4543[10] = %4544)                     # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_0_pass_2.swap_max_value
# %4546 = 0                                       # ClearScalar<uint1>                            ∈ [0, 0]                   @ Stage_0_pass_2.max_label
# %4547 = greater(%4532, %4546)                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_2.max_label
# %4548 = subtract(%4531, %4528)                  # EncryptedTensor<int2, shape=(2,)>             ∈ [-1, 1]                  @ Stage_0_pass_2.max_label
# %4549 = multiply(%4548, %4547)                  # EncryptedTensor<int2, shape=(2,)>             ∈ [-1, 1]                  @ Stage_0_pass_2.max_label
# %4550 = add(%4528, %4549)                       # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_2.max_label
# %4551 = add(%4528, %4531)                       # EncryptedTensor<uint2, shape=(2,)>            ∈ [0, 2]                   @ Stage_0_pass_2.swap_max_label
# %4552 = subtract(%4551, %4550)                  # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4553 = %4552[0]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4554 = (%4519[1] = %4553)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4555 = %4552[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4556 = (%4554[3] = %4555)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4557 = %4550[0]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4558 = (%4556[8] = %4557)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4559 = %4550[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4560 = (%4558[10] = %4559)                     # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_2.swap_max_label
# %4561 = %4545[1]                                # EncryptedScalar<uint16>                       ∈ [22347, 58511]           @ Stage_0_pass_1
# %4562 = %4545[3]                                # EncryptedScalar<uint17>                       ∈ [32439, 69010]           @ Stage_0_pass_1
# %4563 = array([%4561, %4562])                   # EncryptedTensor<uint17, shape=(2,)>           ∈ [22347, 69010]           @ Stage_0_pass_1
# %4564 = %4545[4]                                # EncryptedScalar<uint17>                       ∈ [31944, 70047]           @ Stage_0_pass_1
# %4565 = %4545[6]                                # EncryptedScalar<uint17>                       ∈ [32445, 72866]           @ Stage_0_pass_1
# %4566 = array([%4564, %4565])                   # EncryptedTensor<uint17, shape=(2,)>           ∈ [31944, 72866]           @ Stage_0_pass_1
# %4567 = %4560[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_1
# %4568 = %4560[3]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_1
# %4569 = array([%4567, %4568])                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_1
# %4570 = %4560[4]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_1
# %4571 = %4560[6]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_1
# %4572 = array([%4570, %4571])                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_1
# %4573 = subtract(%4566, %4563)                  # EncryptedTensor<int16, shape=(2,)>            ∈ [-18379, 25760]          @ Stage_0_pass_1.diff
# %4574 = 0                                       # ClearScalar<uint1>                            ∈ [0, 0]                   @ Stage_0_pass_1.max_value
# %4575 = maximum(%4574, %4573)                   # EncryptedTensor<uint15, shape=(2,)>           ∈ [0, 25760]               @ Stage_0_pass_1.max_value
# %4576 = add(%4563, %4575)                       # EncryptedTensor<uint17, shape=(2,)>           ∈ [31944, 72866]           @ Stage_0_pass_1.max_value
# %4577 = add(%4563, %4566)                       # EncryptedTensor<uint18, shape=(2,)>           ∈ [59898, 141531]          @ Stage_0_pass_1.swap_max_value
# %4578 = subtract(%4577, %4576)                  # EncryptedTensor<uint17, shape=(2,)>           ∈ [22347, 68665]           @ Stage_0_pass_1.swap_max_value
# %4579 = %4578[0]                                # EncryptedScalar<uint16>                       ∈ [22347, 58511]           @ Stage_0_pass_1.swap_max_value
# %4580 = (%4545[1] = %4579)                      # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_0_pass_1.swap_max_value
# %4581 = %4578[1]                                # EncryptedScalar<uint17>                       ∈ [32439, 68665]           @ Stage_0_pass_1.swap_max_value
# %4582 = (%4580[3] = %4581)                      # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_0_pass_1.swap_max_value
# %4583 = %4576[0]                                # EncryptedScalar<uint17>                       ∈ [31944, 70047]           @ Stage_0_pass_1.swap_max_value
# %4584 = (%4582[4] = %4583)                      # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_0_pass_1.swap_max_value
# %4585 = %4576[1]                                # EncryptedScalar<uint17>                       ∈ [32916, 72866]           @ Stage_0_pass_1.swap_max_value
# %4586 = (%4584[6] = %4585)                      # EncryptedTensor<uint18, shape=(90,)>          ∈ [0, 257628]              @ Stage_0_pass_1.swap_max_value
# %4587 = 0                                       # ClearScalar<uint1>                            ∈ [0, 0]                   @ Stage_0_pass_1.max_label
# %4588 = greater(%4573, %4587)                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_1.max_label
# %4589 = subtract(%4572, %4569)                  # EncryptedTensor<int2, shape=(2,)>             ∈ [-1, 1]                  @ Stage_0_pass_1.max_label
# %4590 = multiply(%4589, %4588)                  # EncryptedTensor<int2, shape=(2,)>             ∈ [-1, 1]                  @ Stage_0_pass_1.max_label
# %4591 = add(%4569, %4590)                       # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_1.max_label
# %4592 = add(%4569, %4572)                       # EncryptedTensor<uint2, shape=(2,)>            ∈ [0, 2]                   @ Stage_0_pass_1.swap_max_label
# %4593 = subtract(%4592, %4591)                  # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4594 = %4593[0]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4595 = (%4560[1] = %4594)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4596 = %4593[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4597 = (%4595[3] = %4596)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4598 = %4591[0]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4599 = (%4597[4] = %4598)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4600 = %4591[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4601 = (%4599[6] = %4600)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_1.swap_max_label
# %4602 = %4586[1]                                # EncryptedScalar<uint16>                       ∈ [22347, 58511]           @ Stage_0_pass_0
# %4603 = %4586[3]                                # EncryptedScalar<uint17>                       ∈ [32439, 68665]           @ Stage_0_pass_0
# %4604 = array([%4602, %4603])                   # EncryptedTensor<uint17, shape=(2,)>           ∈ [22347, 68665]           @ Stage_0_pass_0
# %4605 = %4586[2]                                # EncryptedScalar<uint17>                       ∈ [27323, 68483]           @ Stage_0_pass_0
# %4606 = %4586[4]                                # EncryptedScalar<uint17>                       ∈ [31944, 70047]           @ Stage_0_pass_0
# %4607 = array([%4605, %4606])                   # EncryptedTensor<uint17, shape=(2,)>           ∈ [27323, 70047]           @ Stage_0_pass_0
# %4608 = %4601[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_0
# %4609 = %4601[3]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_0
# %4610 = array([%4608, %4609])                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_0
# %4611 = %4601[2]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_0
# %4612 = %4601[4]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_0
# %4613 = array([%4611, %4612])                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_0
# %4614 = subtract(%4607, %4604)                  # EncryptedTensor<int16, shape=(2,)>            ∈ [-16886, 24196]          @ Stage_0_pass_0.diff
# %4615 = 0                                       # ClearScalar<uint1>                            ∈ [0, 0]                   @ Stage_0_pass_0.max_label
# %4616 = greater(%4614, %4615)                   # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_0.max_label
# %4617 = subtract(%4613, %4610)                  # EncryptedTensor<int2, shape=(2,)>             ∈ [-1, 1]                  @ Stage_0_pass_0.max_label
# %4618 = multiply(%4617, %4616)                  # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 0]                   @ Stage_0_pass_0.max_label
# %4619 = add(%4610, %4618)                       # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_0.max_label
# %4620 = add(%4610, %4613)                       # EncryptedTensor<uint2, shape=(2,)>            ∈ [0, 2]                   @ Stage_0_pass_0.swap_max_label
# %4621 = subtract(%4620, %4619)                  # EncryptedTensor<uint1, shape=(2,)>            ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4622 = %4621[0]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4623 = (%4601[1] = %4622)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4624 = %4621[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4625 = (%4623[3] = %4624)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4626 = %4619[0]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4627 = (%4625[2] = %4626)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4628 = %4619[1]                                # EncryptedScalar<uint1>                        ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4629 = (%4627[4] = %4628)                      # EncryptedTensor<uint1, shape=(90,)>           ∈ [0, 1]                   @ Stage_0_pass_0.swap_max_label
# %4630 = %4629[0:3]                              # EncryptedTensor<uint1, shape=(3,)>            ∈ [0, 1]
# %4631 = expand_dims(%4630, axis=0)              # EncryptedTensor<uint1, shape=(1, 3)>          ∈ [0, 1]
# return %4631

# %% [markdown]
# Evaluate accuracy performed on the cleartext during prediction

# %%
sd_clear_accuracy = accuracy_score(sd_y_test, sd_y_pred_clear)
sd_clear_precision = precision_score(sd_y_test, sd_y_pred_clear)
sd_clear_recall = recall_score (sd_y_test, sd_y_pred_clear)
sd_clear_f1 = f1_score(sd_y_test, sd_y_pred_clear)
sd_clear_auc = roc_auc_score(sd_y_test, sd_y_pred_clear)
sd_ml_elapsed_time = sd_ml_end_time - sd_ml_start_time

print("Cleartext Accuracy Score: ", sd_clear_accuracy)
print("Cleartext Precision Score: ", sd_clear_precision)
print("Cleartext Recall Score: ", sd_clear_recall)
print("Cleartext F1 Score: ", sd_clear_f1)
print("Cleartext AUC Score: ", sd_clear_auc)
print(f"Time it took for ML to make predictions: {sd_ml_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - Cleartext

# %%
sd_clear_cm = metrics.confusion_matrix(sd_y_test, sd_y_pred_clear)
sd_clear_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=sd_clear_cm)
sd_clear_disp.plot()
plt.title("Confusion Matrix - Cleartext: ")
plt.show()

# %% [markdown]
# Classification Report - Cleartext

# %%
print("Classification Report - Cleartext: ")
print(classification_report(sd_y_test, sd_y_pred_clear))

# %% [markdown]
# FHE Execution and Evaluation

# %%
sd_fhe_prediction_start_time = time.time()

sd_y_pred_fhe = sd_model.predict(sd_x_test, fhe="execute")

sd_fhe_prediction_end_time = time.time()

# %% [markdown]
# Evaluate accuracy performed during FHE prediction

# %%
sd_fhe_accuracy = accuracy_score(sd_y_test, sd_y_pred_fhe)
sd_fhe_precision = precision_score(sd_y_test, sd_y_pred_fhe)
sd_fhe_recall = recall_score (sd_y_test, sd_y_pred_fhe)
sd_fhe_f1 = f1_score(sd_y_test, sd_y_pred_fhe)
sd_fhe_auc = roc_auc_score(sd_y_test, sd_y_pred_fhe)
sd_fhe_prediction_elapsed_time = sd_fhe_prediction_end_time - sd_fhe_prediction_start_time

print("FHE Accuracy Score: ", sd_fhe_accuracy)
print("FHE Precision Score: ", sd_fhe_precision)
print("FHE Recall Score: ", sd_fhe_recall)
print("FHE F1 Score: ", sd_fhe_f1)
print("FHE AUC Score: ", sd_fhe_auc)
print(f"Total time for FHE Execution and Evaluation: {sd_fhe_prediction_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - FHE

# %%
sd_fhe_cm = metrics.confusion_matrix(sd_y_test, sd_y_pred_fhe)
sd_fhe_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=sd_fhe_cm)
sd_fhe_disp.plot()
plt.title("Confusion Matrix - FHE: ")
plt.show()

# %% [markdown]
# Classification Report - FHE

# %%
print("Classification Report - FHE: ")
print(classification_report(sd_y_test, sd_y_pred_fhe))

# %% [markdown]
# Evaluation of SD Model

# %%
print("In clear  :", sd_y_pred_clear)
print("In FHE    :", sd_y_pred_fhe)
print(f"Similarity: {int((sd_y_pred_fhe == sd_y_pred_clear).mean()*100)}%")

sd_total_end_time = time.time()
sd_total_elapsed_time = sd_total_end_time - sd_total_start_time
print(f"Total time for SD to Run: {sd_total_elapsed_time:.5f} seconds")

# %% [markdown]
# # Medium Random Dataset - 1000 samples

# %% [markdown]
# Make classification samples and perform train and test split

# %%
md_x, md_y = make_classification(n_samples=1000, class_sep=2, n_features=30, random_state=42)
print("X Minimum: ", md_x.min())
print("X Maximum: ", md_x.max())

md_x_train, md_x_test, md_y_train, md_y_test = train_test_split(md_x, md_y, test_size=0.1, random_state=42)

# %% [markdown]
# Evaluate number of training and testing samples from train/test split

# %%
num_md_x_training = len(md_x_train)
num_md_x_test = len(md_x_test)
num_md_y_training = len(md_y_train)
num_md_y_test = len(md_y_test)

print("Number of x training: ", num_md_x_training)
print("Number of x test: ", num_md_x_test)
print("Number of y training: ", num_md_y_training)
print("Number of y test: ", num_md_y_test)

# %%
print("md_x_train shape: ", md_x_train.shape)
print("md_x_test shape: ", md_x_test.shape)
print("md_y_train shape: ", md_y_train.shape)
print("md_y_test shape: ", md_y_train.shape)

# %% [markdown]
# Initialise Model and Perform Fitting and Prediction

# %%
md_total_start_time = time.time()

md_model = KNeighborsClassifier(n_bits=8)
md_ml_start_time = time.time()

md_model.fit(md_x_train, md_y_train)
md_y_pred_clear = md_model.predict(md_x_test)
md_model.compile(md_x_train)

md_ml_end_time = time.time()

# %% [markdown]
# Evaluate accuracy performed on the cleartext during prediction

# %%
md_clear_accuracy = accuracy_score(md_y_test, md_y_pred_clear)
md_clear_precision = precision_score(md_y_test, md_y_pred_clear)
md_clear_recall = recall_score (md_y_test, md_y_pred_clear)
md_clear_f1 = f1_score(md_y_test, md_y_pred_clear)
md_clear_auc = roc_auc_score(md_y_test, md_y_pred_clear)
md_ml_elapsed_time = md_ml_end_time - md_ml_start_time

print("Cleartext Accuracy Score: ", md_clear_accuracy)
print("Cleartext Precision Score: ", md_clear_precision)
print("Cleartext Recall Score: ", md_clear_recall)
print("Cleartext F1 Score: ", md_clear_f1)
print("Cleartext AUC Score: ", md_clear_auc)
print(f"Time it took for ML to make predictions: {md_ml_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - FHE

# %%
md_clear_cm = metrics.confusion_matrix(md_y_test, md_y_pred_clear)
md_clear_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=md_clear_cm)
md_clear_disp.plot()
plt.title("Confusion Matrix - Cleartext: ")
plt.show()

# %% [markdown]
# Classification Report - Cleartext

# %%
print("Classification Report - Cleartext: ")
print(classification_report(md_y_test, md_y_pred_clear))

# %% [markdown]
# FHE Execution and Evaluation

# %%
md_fhe_prediction_start_time = time.time()

md_y_pred_fhe = md_model.predict(md_x_test, fhe="execute")

md_fhe_prediction_end_time = time.time()

# %% [markdown]
# Evaluate accuracy performed during FHE prediction

# %%
md_fhe_accuracy = accuracy_score(md_y_test, md_y_pred_fhe)
md_fhe_precision = precision_score(md_y_test, md_y_pred_fhe)
md_fhe_recall = recall_score (md_y_test, md_y_pred_fhe)
md_fhe_f1 = f1_score(md_y_test, md_y_pred_fhe)
md_fhe_auc = roc_auc_score(md_y_test, md_y_pred_fhe)
md_fhe_prediction_elapsed_time = md_fhe_prediction_end_time - md_fhe_prediction_start_time

print("FHE Accuracy Score: ", md_fhe_accuracy)
print("FHE Precision Score: ", md_fhe_precision)
print("FHE Recall Score: ", md_fhe_recall)
print("FHE F1 Score: ", md_fhe_f1)
print("FHE AUC Score: ", md_fhe_auc)
print(f"Total time for FHE Execution and Evaluation: {md_fhe_prediction_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - FHE

# %%
md_fhe_cm = metrics.confusion_matrix(md_y_test, md_y_pred_fhe)
md_fhe_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=md_fhe_cm)
md_fhe_disp.plot()
plt.title("Confusion Matrix - FHE: ")
plt.show()

# %% [markdown]
# Classification Report - FHE

# %%
print("Classification Report - FHE: ")
print(classification_report(md_y_test, md_y_pred_fhe))

# %% [markdown]
# Evaluation of MD Model

# %%
print("In clear  :", md_y_pred_clear)
print("In FHE    :", md_y_pred_fhe)
print(f"Similarity: {int((md_y_pred_fhe == md_y_pred_clear).mean()*100)}%")

md_total_end_time = time.time()
md_total_elapsed_time = md_total_end_time - md_total_start_time
print(f"Total time for MD to Run: {md_total_elapsed_time:.5f} seconds")

# %% [markdown]
# # Large Random Dataset - 10,000 samples

# %% [markdown]
# Make Samples and Perform Train and Test Split

# %%
ld_x, ld_y = make_classification(n_samples=10000, class_sep=2, n_features=30, random_state=42)
print("X Minimum: ", ld_x.min())
print("X Maximum: ", ld_x.max())

ld_x_train, ld_x_test, ld_y_train, ld_y_test = train_test_split(ld_x, ld_y, test_size=0.1, random_state=42)

# %% [markdown]
# Evaluate number of training and testing samples from train/test split

# %%
num_ld_x_training = len(ld_x_train)
num_ld_x_test = len(ld_x_test)
num_ld_y_training = len(ld_y_train)
num_ld_y_test = len(ld_y_test)

print("Number of x training: ", num_ld_x_training)
print("Number of x test: ", num_ld_x_test)
print("Number of y training: ", num_ld_y_training)
print("Number of y test: ", num_ld_y_test)

# %%
print("ld_x_train shape: ", ld_x_train.shape)
print("ld_x_test shape: ", ld_x_test.shape)
print("ld_y_train shape: ", ld_y_train.shape)
print("ld_y_test shape: ", ld_y_train.shape)

# %% [markdown]
# Initialise Model and Perform Fitting and Prediction

# %%
ld_total_start_time = time.time()

ld_model = KNeighborsClassifier(n_bits=8, n_neighbors=3)
ld_ml_start_time = time.time()

ld_model.fit(ld_x_train, ld_y_train)
ld_y_pred_clear = ld_model.predict(ld_x_test)
ld_model.compile(ld_x_train)

ld_ml_end_time = time.time()

# %% [markdown]
# Evaluate accuracy performed on the cleartext during prediction

# %%
ld_clear_accuracy = accuracy_score(ld_y_test, ld_y_pred_clear)
ld_clear_precision = precision_score(ld_y_test, ld_y_pred_clear)
ld_clear_recall = recall_score (ld_y_test, ld_y_pred_clear)
ld_clear_f1 = f1_score(ld_y_test, ld_y_pred_clear)
ld_clear_auc = roc_auc_score(ld_y_test, ld_y_pred_clear)
ld_ml_elapsed_time = ld_ml_end_time - ld_ml_start_time

print("Cleartext Accuracy Score: ", ld_clear_accuracy)
print("Cleartext Precision Score: ", ld_clear_precision)
print("Cleartext Recall Score: ", ld_clear_recall)
print("Cleartext F1 Score: ", ld_clear_f1)
print("Cleartext AUC Score: ", ld_clear_auc)
print(f"Time it took for ML to make predictions: {ld_ml_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - FHE

# %%
ld_clear_cm = metrics.confusion_matrix(ld_y_test, ld_y_pred_clear)
ld_clear_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=ld_clear_cm)
ld_clear_disp.plot()
plt.title("Confusion Matrix - Cleartext: ")
plt.show()

# %% [markdown]
# Classification Report - Cleartext

# %%
print("Classification Report - Cleartext: ")
print(classification_report(ld_y_test, ld_y_pred_clear))

# %% [markdown]
# FHE Execution and Evaluation

# %%
ld_fhe_prediction_start_time = time.time()

ld_y_pred_fhe = md_model.predict(ld_x_test, fhe="execute")

ld_fhe_prediction_end_time = time.time()

# %% [markdown]
# Evaluate accuracy performed during FHE prediction

# %%
ld_fhe_accuracy = accuracy_score(ld_y_test, ld_y_pred_fhe)
ld_fhe_precision = precision_score(ld_y_test, ld_y_pred_fhe)
ld_fhe_recall = recall_score (ld_y_test, ld_y_pred_fhe)
ld_fhe_f1 = f1_score(ld_y_test, ld_y_pred_fhe)
ld_fhe_auc = roc_auc_score(ld_y_test, ld_y_pred_fhe)
ld_fhe_prediction_elapsed_time = ld_fhe_prediction_end_time - ld_fhe_prediction_start_time

print("FHE Accuracy Score: ", ld_fhe_accuracy)
print("FHE Precision Score: ", ld_fhe_precision)
print("FHE Recall Score: ", ld_fhe_recall)
print("FHE F1 Score: ", ld_fhe_f1)
print("FHE AUC Score: ", ld_fhe_auc)
print(f"Total time for FHE Execution and Evaluation: {ld_fhe_prediction_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - FHE

# %%
ld_fhe_cm = metrics.confusion_matrix(ld_y_test, ld_y_pred_fhe)
ld_fhe_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=ld_fhe_cm)
ld_fhe_disp.plot()
plt.title("Confusion Matrix - FHE: ")
plt.show()

# %% [markdown]
# Classification Report - FHE

# %%
print("Classification Report - FHE: ")
print(classification_report(ld_y_test, ld_y_pred_fhe))

# %% [markdown]
# Evaluation of LD Model

# %%
print("In clear  :", ld_y_pred_clear)
print("In FHE    :", ld_y_pred_fhe)
print(f"Similarity: {int((ld_y_pred_fhe == ld_y_pred_clear).mean()*100)}%")

ld_total_end_time = time.time()
ld_total_elapsed_time = ld_total_end_time - ld_total_start_time
print(f"Total time for MD to Run: {ld_total_elapsed_time:.5f} seconds")

# %% [markdown]
# # High Random Dataset - 100,000 samples

# %% [markdown]
# Makes Samples and Perform Train and Test Split

# %%
hd_x, hd_y = make_classification(n_samples=100000, class_sep=2, n_features=30, random_state=42)
print("X Minimum: ", hd_x.min())
print("X Maximum: ", hd_x.max())

hd_x_train, hd_x_test, hd_y_train, hd_y_test = train_test_split(hd_x, hd_y, test_size=0.1, random_state=42)

# %% [markdown]
# Evaluate number of training and testing samples from train/test split

# %%
num_hd_x_training = len(hd_x_train)
num_hd_x_test = len(hd_x_test)
num_hd_y_training = len(hd_y_train)
num_hd_y_test = len(hd_y_test)

print("Number of x training: ", num_hd_x_training)
print("Number of x test: ", num_hd_x_test)
print("Number of y training: ", num_hd_y_training)
print("Number of y test: ", num_hd_y_test)

# %%
print("hd_x_train shape: ", hd_x_train.shape)
print("hd_x_test shape: ", hd_x_test.shape)
print("hd_y_train shape: ", hd_y_train.shape)
print("hd_y_test shape: ", hd_y_train.shape)

# %% [markdown]
# Initialise Model and Perform Fitting and Prediction

# %%
hd_total_start_time = time.time()

hd_model = KNeighborsClassifier(n_bits=8, n_neighbors=3)
hd_ml_start_time = time.time()

hd_model.fit(hd_x_train, hd_y_train)
hd_y_pred_clear = hd_model.predict(hd_x_test)
hd_model.compile(hd_x_train)

hd_ml_end_time = time.time()

# %% [markdown]
# Evaluate accuracy performed on the cleartext during prediction

# %%
hd_clear_accuracy = accuracy_score(hd_y_test, hd_y_pred_clear)
hd_clear_precision = precision_score(hd_y_test, hd_y_pred_clear)
hd_clear_recall = recall_score (hd_y_test, hd_y_pred_clear)
hd_clear_f1 = f1_score(hd_y_test, hd_y_pred_clear)
hd_clear_auc = roc_auc_score(hd_y_test, hd_y_pred_clear)
hd_ml_elapsed_time = hd_ml_end_time - hd_ml_start_time

print("Cleartext Accuracy Score: ", hd_clear_accuracy)
print("Cleartext Precision Score: ", hd_clear_precision)
print("Cleartext Recall Score: ", hd_clear_recall)
print("Cleartext F1 Score: ", hd_clear_f1)
print("Cleartext AUC Score: ", hd_clear_auc)
print(f"Time it took for ML to make predictions: {hd_ml_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - Cleartext

# %%
hd_clear_cm = metrics.confusion_matrix(hd_y_test, hd_y_pred_clear)
hd_clear_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=hd_clear_cm)
hd_clear_disp.plot()
plt.title("Confusion Matrix - Cleartext: ")
plt.show()

# %% [markdown]
# Classification Report - Cleartext

# %%
print("Classification Report - Cleartext: ")
print(classification_report(hd_y_test, hd_y_pred_clear))

# %% [markdown]
# FHE Execution and Evaluation

# %%
hd_fhe_prediction_start_time = time.time()

hd_y_pred_fhe = hd_model.predict(hd_x_test, fhe="execute")

hd_fhe_prediction_end_time = time.time()

# %% [markdown]
# Evaluate accuracy performed during FHE prediction

# %%
hd_fhe_accuracy = accuracy_score(hd_y_test, hd_y_pred_fhe)
hd_fhe_precision = precision_score(hd_y_test, hd_y_pred_fhe)
hd_fhe_recall = recall_score (hd_y_test, hd_y_pred_fhe)
hd_fhe_f1 = f1_score(hd_y_test, hd_y_pred_fhe)
hd_fhe_auc = roc_auc_score(hd_y_test, hd_y_pred_fhe)
hd_fhe_prediction_elapsed_time = hd_fhe_prediction_end_time - hd_fhe_prediction_start_time

print("FHE Accuracy Score: ", hd_fhe_accuracy)
print("FHE Precision Score: ", hd_fhe_precision)
print("FHE Recall Score: ", hd_fhe_recall)
print("FHE F1 Score: ", hd_fhe_f1)
print("FHE AUC Score: ", hd_fhe_auc)
print(f"Total time for FHE Execution and Evaluation: {hd_fhe_prediction_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - FHE

# %%
hd_fhe_cm = metrics.confusion_matrix(hd_y_test, hd_y_pred_fhe)
hd_fhe_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=hd_fhe_cm)
hd_fhe_disp.plot()
plt.title("Confusion Matrix - FHE: ")
plt.show()

# %% [markdown]
# Classification Report - FHE

# %%
print("Classification Report - FHE: ")
print(classification_report(hd_y_test, hd_y_pred_fhe))

# %% [markdown]
# Evaluation of HD Model

# %%
print("In clear  :", hd_y_pred_clear)
print("In FHE    :", hd_y_pred_fhe)
print(f"Similarity: {int((hd_y_pred_fhe == hd_y_pred_clear).mean()*100)}%")

hd_total_end_time = time.time()
hd_total_elapsed_time = hd_total_end_time - hd_total_start_time
print(f"Total time for HD to Run: {hd_total_elapsed_time:.5f} seconds")

# %% [markdown]
# # Mega Random Dataset - 1,000,000 samples

# %% [markdown]
# Makes Samples and Perform Train and Test Split

# %%
bd_x, bd_y = make_classification(n_samples=1000000, class_sep=2, n_features=30, random_state=42)
print("X Minimum: ", bd_x.min())
print("X Maximum: ", bd_x.max())

bd_x_train, bd_x_test, bd_y_train, bd_y_test = train_test_split(bd_x, bd_y, test_size=0.1, random_state=42)

# %% [markdown]
# Evalaute number of training and testing samples from train/test split

# %%
num_bd_x_training = len(bd_x_train)
num_bd_x_test = len(bd_x_test)
num_bd_y_training = len(bd_y_train)
num_bd_y_test = len(bd_y_test)

print("Number of x training: ", num_bd_x_training)
print("Number of x test: ", num_bd_x_test)
print("Number of y training: ", num_bd_y_training)
print("Number of y test: ", num_bd_y_test)

# %%
print("bd_x_train shape: ", bd_x_train.shape)
print("bd_x_test shape: ", bd_x_test.shape)
print("bd_y_train shape: ", bd_y_train.shape)
print("bd_y_test shape: ", bd_y_train.shape)

# %% [markdown]
# Initialise Model and Perform Fitting and Prediction

# %%
bd_total_start_time = time.time()

bd_model = KNeighborsClassifier(n_bits=8, n_neighbors=3)
bd_ml_start_time = time.time()

bd_model.fit(bd_x_train, bd_y_train)
bd_y_pred_clear = bd_model.predict(bd_x_test)
bd_model.compile(bd_x_train)

bd_ml_end_time = time.time()

# %% [markdown]
# Evaluate accuracy performed on the cleartext during prediction

# %%
bd_clear_accuracy = accuracy_score(bd_y_test, bd_y_pred_clear)
bd_clear_precision = precision_score(bd_y_test, bd_y_pred_clear)
bd_clear_recall = recall_score (bd_y_test, bd_y_pred_clear)
bd_clear_f1 = f1_score(bd_y_test, bd_y_pred_clear)
bd_clear_auc = roc_auc_score(bd_y_test, bd_y_pred_clear)
bd_ml_elapsed_time = bd_ml_end_time - bd_ml_start_time

print("Cleartext Accuracy Score: ", bd_clear_accuracy)
print("Cleartext Precision Score: ", bd_clear_precision)
print("Cleartext Recall Score: ", bd_clear_recall)
print("Cleartext F1 Score: ", bd_clear_f1)
print("Cleartext AUC Score: ", bd_clear_auc)
print(f"Time it took for ML to make predictions: {bd_ml_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - Cleartext

# %%
bd_clear_cm = metrics.confusion_matrix(bd_y_test, bd_y_pred_clear)
bd_clear_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=bd_clear_cm)
bd_clear_disp.plot()
plt.title("Confusion Matrix - Cleartext: ")
plt.show()

# %% [markdown]
# Classification Report - Cleartext

# %%
print("Classification Report - Cleartext: ")
print(classification_report(bd_y_test, bd_y_pred_clear))

# %% [markdown]
# FHE Execution and Evaluation

# %%
bd_fhe_prediction_start_time = time.time()

bd_y_pred_fhe = bd_model.predict(bd_x_test, fhe="execute")

bd_fhe_prediction_end_time = time.time()

# %%
bd_fhe_accuracy = accuracy_score(bd_y_test, bd_y_pred_fhe)
bd_fhe_precision = precision_score(bd_y_test, bd_y_pred_fhe)
bd_fhe_recall = recall_score (bd_y_test, bd_y_pred_fhe)
bd_fhe_f1 = f1_score(bd_y_test, bd_y_pred_fhe)
bd_fhe_auc = roc_auc_score(bd_y_test, bd_y_pred_fhe)
bd_fhe_prediction_elapsed_time = bd_fhe_prediction_end_time - bd_fhe_prediction_start_time

print("FHE Accuracy Score: ", bd_fhe_accuracy)
print("FHE Precision Score: ", bd_fhe_precision)
print("FHE Recall Score: ", bd_fhe_recall)
print("FHE F1 Score: ", bd_fhe_f1)
print("FHE AUC Score: ", bd_fhe_auc)
print(f"Total time for FHE Execution and Evaluation: {bd_fhe_prediction_elapsed_time:.5f} seconds")

# %% [markdown]
# Confusion Matrix - FHE

# %%
bd_fhe_cm = metrics.confusion_matrix(bd_y_test, bd_y_pred_fhe)
bd_fhe_disp = metrics.ConfusionMatrixDisplay(confusion_matrix=bd_fhe_cm)
bd_fhe_disp.plot()
plt.title("Confusion Matrix - FHE: ")
plt.show()

# %% [markdown]
# Classification Report - FHE

# %%
print("Classification Report - FHE: ")
print(classification_report(bd_y_test, bd_y_pred_fhe))

# %% [markdown]
# Evaluation of BD Model

# %%
print("In clear  :", bd_y_pred_clear)
print("In FHE    :", bd_y_pred_fhe)
print(f"Similarity: {int((bd_y_pred_fhe == bd_y_pred_clear).mean()*100)}%")

bd_total_end_time = time.time()
bd_total_elapsed_time = bd_total_end_time - bd_total_start_time
print(f"Total time for BD to Run: {bd_total_elapsed_time:.5f} seconds")

# %% [markdown]
# # Evaluation of all results

# %%
results = {
     '100 Dataset':["100", 
     f"{(sd_y_pred_fhe == sd_y_pred_clear).mean() * 100:.0f}%", 
     sd_ml_elapsed_time,
     sd_clear_accuracy,
     sd_clear_precision,
     sd_clear_recall,
     sd_clear_f1,
     sd_clear_auc,
     sd_fhe_prediction_elapsed_time,
     sd_fhe_accuracy,
     sd_fhe_precision,
     sd_fhe_recall,
     sd_fhe_f1,
     sd_fhe_auc, 
     sd_total_elapsed_time],
     '1000 Dataset':["100", 
     f"{(md_y_pred_fhe == md_y_pred_clear).mean() * 100:.0f}%", 
     md_ml_elapsed_time,
     md_clear_accuracy,
     md_clear_precision,
     md_clear_recall,
     md_clear_f1,
     md_clear_auc,
     md_fhe_prediction_elapsed_time,
     md_fhe_accuracy,
     md_fhe_precision,
     md_fhe_recall,
     md_fhe_f1,
     md_fhe_auc, 
     md_total_elapsed_time],
     '10,000 Dataset':["100", 
     f"{(ld_y_pred_fhe == ld_y_pred_clear).mean() * 100:.0f}%", 
     ld_ml_elapsed_time,
     ld_clear_accuracy,
     ld_clear_precision,
     ld_clear_recall,
     ld_clear_f1,
     ld_clear_auc,
     ld_fhe_prediction_elapsed_time,
     ld_fhe_accuracy,
     ld_fhe_precision,
     ld_fhe_recall,
     ld_fhe_f1,
     ld_fhe_auc, 
     ld_total_elapsed_time],
     '100,000 Dataset':["100", 
     f"{(hd_y_pred_fhe == hd_y_pred_clear).mean() * 100:.0f}%", 
     hd_ml_elapsed_time,
     hd_clear_accuracy,
     hd_clear_precision,
     hd_clear_recall,
     hd_clear_f1,
     hd_clear_auc,
     hd_fhe_prediction_elapsed_time,
     hd_fhe_accuracy,
     hd_fhe_precision,
     hd_fhe_recall,
     hd_fhe_f1,
     hd_fhe_auc, 
     hd_total_elapsed_time],
     '1,000,000 Dataset':["100", 
     f"{(hd_y_pred_fhe == hd_y_pred_clear).mean() * 100:.0f}%", 
     bd_ml_elapsed_time,
     bd_clear_accuracy,
     bd_clear_precision,
     bd_clear_recall,
     bd_clear_f1,
     bd_clear_auc,
     bd_fhe_prediction_elapsed_time,
     bd_fhe_accuracy,
     bd_fhe_precision,
     bd_fhe_recall,
     bd_fhe_f1,
     bd_fhe_auc, 
     bd_total_elapsed_time]
}

headers = ['Samples', 'Similarity', 'ML Time','CT Accuracy', 'CT Precision', 'CT Recall', 'CT F1', 
           'CT AUC', 'FHE Time', 'FHE Accuracy', 'FHE Precision', 'FHE Recall', 'FHE F1', 'FHE AUC', 'Total Time']

overall_results = pd.DataFrame(results, index=headers).T.round(2)
overall_results
